# %% [markdown]
# # ML ASS

# %% [markdown]
# ### Q1) NAME , 10th BOARD
#
# ### Q2) 10th  MARKS , 12th MARKS , SALARY
#
# ### Q3) WRONG because model not going to be trained with J&K BOARD
#
# ### Q4)  AGE , 10th Board , 10th Marks , 12th Marks
#
# ### Q5) One Hot Encoding

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/NOOMAN KHAN/Downloads/Ad-Dataset.xlsx - Company_data.csv")
df.head()
# Out:
#        City     TV  Radio  Newspaper  Sales
# 0     Delhi  230.1   37.8       69.2   22.1
# 1    Mumbai   44.5   39.3       45.1   10.4
# 2  Kolkata    17.2   45.9       69.3   12.0
# 3    Mumbai  151.5   41.3       58.5   16.5
# 4     Delhi  180.8   10.8       58.4   17.9

# %%
# Q2. Find the following values for the TV, Radio, Newspaper column of Advertisement
# Dataset.
# (i) Median (ii) Mode (iii) Max (iv) Min (v) Mean

import statistics
print(df["Radio"].median())
print(statistics.mode(df["Radio"]))
print(df["Radio"].max())
print(df["Radio"].min())
print(df["Radio"].mean())
# Out:
# 22.9
# 4.1
# 49.6
# 0.0
# 23.264000000000024

# %%
#  Print the average spending on Newspaper of each city from
df.groupby(["City"])["Newspaper"].mean().reset_index()
# Out:
#         City  Newspaper
# 0  Bengaluru  28.416667
# 1    Chennai  28.475000
# 2      Delhi  32.090566
# 3     Delhi   27.950000
# 4     Jaipur  29.591667
# 5   Kolkata   30.869231
# 6     Mumbai  28.637037
# 7     Nagpur  39.241667
# 8    Solapur  30.500000
# 9    Udaipur  30.333333

# %%
# Draw scatter plot between Radio and Newspaper column of Advertisement Dataset
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.scatterplot(data = df , x = "Radio" , y = "Newspaper")
plt.show()

# %%
# How many different cities are in the city column of
df["City"].nunique()
# Out:
# 10

# %%
# What is the correlation between TV and Radio columns
df[["TV" , "Radio"]].corr()
# Out:
#              TV     Radio
# TV     1.000000  0.054809
# Radio  0.054809  1.000000

# %%
# What type of encoding we have to apply on the city column on the Advertisemen
#ANS ==  Label encoding

# %%
# What is pearson correlation? Find the pearson correlation between TV, Radio,
# Newspaper and sales columns 
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
# What is the ratio of sales and TV columns of
df1 = df.copy()
df1["Ratio"] = df["Sales"]/df["TV"]
df1
# Out:
#           City     TV  Radio  Newspaper  Sales     Ratio
# 0        Delhi  230.1   37.8       69.2   22.1  0.096045
# 1       Mumbai   44.5   39.3       45.1   10.4  0.233708
# 2     Kolkata    17.2   45.9       69.3   12.0  0.697674
# 3       Mumbai  151.5   41.3       58.5   16.5  0.108911
# 4        Delhi  180.8   10.8       58.4   17.9  0.099004
# ..         ...    ...    ...        ...    ...       ...
# 195     Mumbai   38.2    3.7       13.8    7.6  0.198953
# 196    Udaipur   94.2    4.9        8.1   14.0  0.148620
# 197    Solapur  177.0    9.3        6.4   14.8  0.083616
# 198  Bengaluru  283.6   42.0       66.2   25.5  0.089915
# 199     Mumbai  232.1    8.6        8.7   18.4  0.079276
#
# [200 rows x 6 columns]

# %%
# Filter the Delhi city data from the table 
df[df["City"] == "Delhi"]
# Out:
#       City     TV  Radio  Newspaper  Sales
# 0    Delhi  230.1   37.8       69.2   22.1
# 4    Delhi  180.8   10.8       58.4   17.9
# 8    Delhi    8.6    2.1        1.0    4.8
# 12   Delhi   23.8   35.1       65.9    9.2
# 16   Delhi   67.8   36.6      114.0   12.5
# 20   Delhi  218.4   27.7       53.4   18.0
# 24   Delhi   62.3   12.6       18.3    9.7
# 28   Delhi  248.8   27.1       22.9   18.9
# 32   Delhi   97.2    1.5       30.0   13.2
# 36   Delhi  266.9   43.8        5.0   25.4
# 40   Delhi  202.5   22.3       31.6   16.6
# 44   Delhi   25.1   25.7       43.3    8.5
# 48   Delhi  227.2   15.8       49.9   19.8
# 52   Delhi  216.4   41.7       39.6   22.6
# 54   Delhi  262.7   28.8       15.9   20.2
# 61   Delhi  261.3   42.7       54.7   24.2
# 63   Delhi  102.7   29.6        8.4   14.0
# 70   Delhi  199.1   30.6       38.7   18.3
# 72   Delhi   26.8   33.0       19.3    8.8
# 79   Delhi  116.0    7.7       23.1   11.0
# 81   Delhi  239.8    4.1       36.9   17.3
# ...

# %%
df
# Out:
#           City     TV  Radio  Newspaper  Sales
# 0        Delhi  230.1   37.8       69.2   22.1
# 1       Mumbai   44.5   39.3       45.1   10.4
# 2     Kolkata    17.2   45.9       69.3   12.0
# 3       Mumbai  151.5   41.3       58.5   16.5
# 4        Delhi  180.8   10.8       58.4   17.9
# ..         ...    ...    ...        ...    ...
# 195     Mumbai   38.2    3.7       13.8    7.6
# 196    Udaipur   94.2    4.9        8.1   14.0
# 197    Solapur  177.0    9.3        6.4   14.8
# 198  Bengaluru  283.6   42.0       66.2   25.5
# 199     Mumbai  232.1    8.6        8.7   18.4
#
# [200 rows x 5 columns]
