# %%
# import neccesary packeges
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# load dataset
data = pd.read_csv("C:/Users/NOOMAN KHAN/Downloads/Dataset- Telecom-1.xlsx - telecom_data.csv")
data.head()
# Out:
#     SUBS_KEY  TARGET  OG_MOU_F4  IC_MOU_F4  OG_CALLS_F4  IC_CALLS_F4  \
# 0  623576580       1       2.93       0.00            1            0
# 1  623576616       0      23.03      59.03            6           14
# 2  623576617       0      16.25      24.73           12           18
# 3  623576618       1       3.27       6.42            4           10
# 4  623576655       1       0.00       0.00            0            0
#
#    RCHG_AMOUNT_F4  CNT_RCHG_F4  AVG_MBL_F4  IC_OG_RATIO_F4  ...  \
# 0               0            0        9.12            0.00  ...
# 1               0            0        1.33            2.56  ...
# 2              95            2       16.48            1.52  ...
# 3               0            0        7.70            1.96  ...
# 4               0            0       10.00          999.00  ...
#
#    AVG_NIG_USG_F10  AVG_STD_USG_F4  AVG_STD_USG_F7  AVG_STD_USG_F10  DND  \
# 0             0.00            0.00            0.00             0.00    0
# ...

# %%
# information about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Columns: 109 entries, SUBS_KEY to TARGET_21_30
# dtypes: float64(47), int64(62)
# memory usage: 4.2 MB

# %%
data.isnull().sum()
# Out:
# SUBS_KEY            0
# TARGET              0
# OG_MOU_F4           0
# IC_MOU_F4           0
# OG_CALLS_F4         0
#                    ..
# DND_INFO            0
# CHG_IC_MOU_L5_F5    0
# USAGE_SPREAD        0
# SUM_RCHG_MRP_L10    0
# TARGET_21_30        0
# Length: 109, dtype: int64

# %%
for i in data.columns[data.nunique() == 1]:
    data = data.drop(i , axis = 1)

# %%
# The sales manager wants to know about a customer who has the highest recharge in the first 7
# days and how many days that customer is on VLR (being on the network) in the first 10 days?
data
# Out:
#        SUBS_KEY  TARGET  OG_MOU_F4  IC_MOU_F4  OG_CALLS_F4  IC_CALLS_F4  \
# 0     623576580       1       2.93       0.00            1            0
# 1     623576616       0      23.03      59.03            6           14
# 2     623576617       0      16.25      24.73           12           18
# 3     623576618       1       3.27       6.42            4           10
# 4     623576655       1       0.00       0.00            0            0
# ...         ...     ...        ...        ...          ...          ...
# 4995  623614881       1       0.00       0.97            1            3
# 4996  623614882       0       3.63       9.70            6            9
# 4997  623614883       1       0.00       0.00            0            0
# 4998  623614884       0      11.02       1.97            8            2
# 4999  623614885       1       0.00       0.37            0            1
#
#       RCHG_AMOUNT_F4  CNT_RCHG_F4  AVG_MBL_F4  IC_OG_RATIO_F4  ...  \
# ...
