# %%
# imortings module
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
#  2. Perform the following operations on the penguins dataset
#
#
# ---
#
#
#
# 1. Print first 25 entries
# 2. Print last 10 entries
# 3. Print number of rows and columns in the dataset
# 4. Print names of all the columns
# 5. What is the data type of each column
# 6. Print only species column
# 7. How many different types of species are their in this dataset
# 8. What is the most popular species
# 9. Summarize the DataFrame
# 10. Summarize all the columns
# 11. Summarize only bill_length_mm column
# 12. what is the mean of body_mass_g
# 13. How many different islands are there in this dataset and print their names
# 14. Find total count of occurenace of each gender
# 15. Print rows 3-9
# 16. Select every row after the fourth row and all columns
# 17. Select every row upto 4th row and all columns
# 18. Select rows where bill_length_mm is greater than 39
# 19. Select the rows with index 3 & 5
# 18. For each island, calculate minimum and maximum flipper_length_mm
# 19. Find the average flipper_length_mm for each gender
# 20. Plot line graph between flipper_length_mm vs bill_depth_mm
# 21. Plot scatter plot between flipper_length_mm vs bill_depth_mm with gender as hue.

# %%
# Print first 25 entries
df.iloc[:25,:]
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
# Print first 25 entries
df.head(25)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
# Print last 10 entries
df.tail(10)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 334  Gentoo  Biscoe            46.2           14.1              217.0
# 335  Gentoo  Biscoe            55.1           16.0              230.0
# 336  Gentoo  Biscoe            44.5           15.7              217.0
# 337  Gentoo  Biscoe            48.8           16.2              222.0
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 334       4375.0  Female
# 335       5850.0    Male
# 336       4875.0     NaN
# 337       6000.0    Male
# 338       4925.0  Female
# 339          NaN     NaN
# ...

# %%
df.iloc[len(df)-10:len(df),:]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 334  Gentoo  Biscoe            46.2           14.1              217.0
# 335  Gentoo  Biscoe            55.1           16.0              230.0
# 336  Gentoo  Biscoe            44.5           15.7              217.0
# 337  Gentoo  Biscoe            48.8           16.2              222.0
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 334       4375.0  Female
# 335       5850.0    Male
# 336       4875.0     NaN
# 337       6000.0    Male
# 338       4925.0  Female
# 339          NaN     NaN
# ...

# %%
# Print number of rows and columns in the dataset
df.shape[0]
# Out:
# 344

# %%
# Print names of all the columns
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# What is the data type of each column
df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
# Print only species column
df[["species"]]
# Out:
#     species
# 0    Adelie
# 1    Adelie
# 2    Adelie
# 3    Adelie
# 4    Adelie
# ..      ...
# 339  Gentoo
# 340  Gentoo
# 341  Gentoo
# 342  Gentoo
# 343  Gentoo
#
# [344 rows x 1 columns]

# %%
# How many different types of species are their in this dataset
df["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
#  What is the most popular specie
df["species"].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
# Summarize the DataFrame
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# Summarize only bill_length_mm column
df.describe()["bill_length_mm"]
# Out:
# count    342.000000
# mean      43.921930
# std        5.459584
# min       32.100000
# 25%       39.225000
# 50%       44.450000
# 75%       48.500000
# max       59.600000
# Name: bill_length_mm, dtype: float64

# %%
df["body_mass_g"].mean()
# Out:
# 4201.754385964912

# %% [markdown]
# How many different islands are there in this dataset and print their names
#
# Find total count of occurenace of each gender
#
# Print rows 3-9
#
# Select every row after the fourth row and all columns
#
# Select every row upto 4th row and all columns
#
# Select rows where bill_length_mm is greater than 39
#
# Select the rows with index 3 & 5
#
# For each island, calculate minimum and maximum flipper_length_mm
#
# Find the average flipper_length_mm for each gender
#
# Plot line graph between flipper_length_mm vs bill_depth_mm
#
# Plot scatter plot between flipper_length_mm vs bill_depth_mm with gender as hue.

# %%
df["island"].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df["sex"].value_counts()
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
df.iloc[3:10,:]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female
# 7       4675.0    Male
# 8       3475.0     NaN
# 9       4250.0     NaN

# %%
df.iloc[:4,:]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN

# %%
df[df["bill_length_mm"]>35]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.loc[3]
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm             NaN
# bill_depth_mm              NaN
# flipper_length_mm          NaN
# body_mass_g                NaN
# sex                        NaN
# Name: 3, dtype: object

# %%
df.loc[5]
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            39.3
# bill_depth_mm             20.6
# flipper_length_mm        190.0
# body_mass_g             3650.0
# sex                       Male
# Name: 5, dtype: object

# %%
df.groupby(["island"]).agg({"bill_length_mm":["min","max"]})
# Out:
#           bill_length_mm
#                      min   max
# island
# Biscoe              34.5  59.6
# Dream               32.1  58.0
# Torgersen           33.5  46.0

# %%
df.groupby(["sex"])["flipper_length_mm"].mean().reset_index()
# Out:
#       sex  flipper_length_mm
# 0  Female         197.363636
# 1    Male         204.505952

# %%
sns.lineplot(x = df["bill_depth_mm"] , y = df["flipper_length_mm"] , color = "blue")
plt.show()

# %%
sns.scatterplot(x = df["bill_depth_mm"] , y = df["flipper_length_mm"] , color = "blue" , hue = df["sex"])
plt.show()

# %% [markdown]
# EDA

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
fig , ax = plt.subplots(2,2,figsize = (15,10))
numeric = ["int32","int64","float32","float64"]
cols = df.select_dtypes(include = numeric).columns
index = 0
for i in range(2):
    for j in range(2):
        sns.violinplot(y = df[cols[index]] , x = df["sex"] , ax = ax[i][j])
        index +=1

# %%
fig , ax = plt.subplots(2,2,figsize = (15,10))
numeric = ["int32","int64","float32","float64"]
cols = df.select_dtypes(include = numeric).columns
index = 0
for i in range(2):
    for j in range(2):
        sns.barplot(y = df[cols[index]] , x = df["sex"] , ax = ax[i][j])
        index +=1

# %%
df["Sex"] = np.where(df["sex"]=="Male",1,0)

# %%
sns.countplot(x = df["species"] , hue = df["sex"])
plt.show()

# %%
sns.countplot(x = df["island"] , hue = df["sex"])
plt.show()

# %% [markdown]
# target is not depend on species and island let's drop it

# %%
df = df.drop(["species","island","sex"],axis = 1)

# %%
df
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  Sex
# 0              39.1           18.7              181.0       3750.0    1
# 1              39.5           17.4              186.0       3800.0    0
# 2              40.3           18.0              195.0       3250.0    0
# 3               NaN            NaN                NaN          NaN    0
# 4              36.7           19.3              193.0       3450.0    0
# ..              ...            ...                ...          ...  ...
# 339             NaN            NaN                NaN          NaN    0
# 340            46.8           14.3              215.0       4850.0    0
# 341            50.4           15.7              222.0       5750.0    1
# 342            45.2           14.8              212.0       5200.0    0
# 343            49.9           16.1              213.0       5400.0    1
#
# [344 rows x 5 columns]

# %%
# filling null

# %%
df.isnull().sum()
# Out:
# bill_length_mm       2
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# Sex                  0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# Sex                  0
# dtype: int64

# %%
df
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  Sex
# 0              39.1           18.7              181.0       3750.0    1
# 1              39.5           17.4              186.0       3800.0    0
# 2              40.3           18.0              195.0       3250.0    0
# 4              36.7           19.3              193.0       3450.0    0
# 5              39.3           20.6              190.0       3650.0    1
# ..              ...            ...                ...          ...  ...
# 338            47.2           13.7              214.0       4925.0    0
# 340            46.8           14.3              215.0       4850.0    0
# 341            50.4           15.7              222.0       5750.0    1
# 342            45.2           14.8              212.0       5200.0    0
# 343            49.9           16.1              213.0       5400.0    1
#
# [342 rows x 5 columns]

# %%
X = df.drop("Sex" , axis = 1)
Y = df[["Sex"]]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_test = sc.fit_transform(X_test)
X_train = sc.transform(X_train)
# Out:
# C:\Users\NOOMAN KHAN\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
# !pip install lazypredict

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose = 0,ignore_warnings = True,custom_metric = None,)
models,prediction = clf.fit(X_train , X_test ,Y_train,Y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 16.64it/s]

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 0.49               0.50     0.50      0.33
# LogisticRegression                 0.49               0.50     0.50      0.33
# XGBClassifier                      0.49               0.50     0.50      0.33
# SVC                                0.49               0.50     0.50      0.33
# SGDClassifier                      0.49               0.50     0.50      0.33
# RidgeClassifierCV                  0.49               0.50     0.50      0.33
# RidgeClassifier                    0.49               0.50     0.50      0.33
# RandomForestClassifier             0.49               0.50     0.50      0.33
# QuadraticDiscriminantAnalysis      0.51               0.50     0.50      0.34
# Perceptron                         0.49               0.50     0.50      0.33
# PassiveAggressiveClassifier        0.49               0.50     0.50      0.33
# ...
