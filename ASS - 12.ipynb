# %% [markdown]
# ##### 1. Calculate entropy for the following data.
# ##### X = {a,a,a,a,b,b,b,b}
#
# ##### H(x) = -0.5*log2 0.5 - 0.5*log2 0.5
#
# ##### H(x) = 1
#
#
#
# ##### Y = {a,a,a,a}
#
# ##### H(x) = -4/4*log2 (4/4)
#
# ##### H(x) = 0
#
#
# ##### Z = {a,a,a,a,a,b,b,b}
#
# ##### H(x) = -5/8*log2 (5/8) - 3/8*log2 (3/8)
#
# ##### H(x) = 0.95

# %% [markdown]
# (a) Use the above data (outlook, temperature, humidity and wind as the
#
# features and the class label is play which has two values yes or no. Based on the given
#
# 4 features a child goes out to play or not) and find out Gini index for each of the four
#
# features and based on the Gini values select the feature that will be used to make the
#
# first split.
#
# (b) Instead of using Gini index, calculate information gain for all the features
#
# and based on information gain values select the feature that will be used to make the
#
# first split.

# %%
import pandas as pd
df = pd.read_excel("C:/Users/NOOMAN KHAN/Desktop/ASS-12.xlsx")
df = df.drop(["Unnamed: 5"] , axis = 1)

# %%
df
# Out:
#      outlook temperature humidity    wind play
# 0      sunny         hot     high    weak   no
# 1      sunny         hot     high  strong   no
# 2   overcast         hot     high    weak  yes
# 3       rain        mild     high    weak  yes
# 4       rain        cool   normal    weak  yes
# 5       rain        cool   normal  strong   no
# 6   overcast        cool   normal  strong  yes
# 7      sunny        mild     high    weak   no
# 8      sunny        cool   normal    weak  yes
# 9       rain        mild   normal    weak  yes
# 10     sunny        mild   normal  strong  yes
# 11  overcast        mild     high  strong  yes
# 12  overcast         hot   normal    weak  yes
# 13      rain        mild     high  strong   no

# %%
import numpy as np
df["play"] = np.where(df["play"]=="yes",1,0)

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]

# %%
X
# Out:
#      outlook temperature humidity    wind
# 0      sunny         hot     high    weak
# 1      sunny         hot     high  strong
# 2   overcast         hot     high    weak
# 3       rain        mild     high    weak
# 4       rain        cool   normal    weak
# 5       rain        cool   normal  strong
# 6   overcast        cool   normal  strong
# 7      sunny        mild     high    weak
# 8      sunny        cool   normal    weak
# 9       rain        mild   normal    weak
# 10     sunny        mild   normal  strong
# 11  overcast        mild     high  strong
# 12  overcast         hot   normal    weak
# 13      rain        mild     high  strong

# %%
Y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# Name: play, dtype: int32

# %%
for i in X.columns:
    X = pd.get_dummies(data = X , columns = [i] , drop_first = True)

# %%
from sklearn import  tree
dt = tree.DecisionTreeClassifier()
dt.fit(X,Y)`
# Out:
#   Input In [25]
#     dt.fit(X,Y)`
#                ^
# SyntaxError: invalid syntax

# %%
X
# Out:
#     outlook_rain  outlook_sunny  temperature_hot  temperature_mild  \
# 0              0              1                1                 0
# 1              0              1                1                 0
# 2              0              0                1                 0
# 3              1              0                0                 1
# 4              1              0                0                 0
# 5              1              0                0                 0
# 6              0              0                0                 0
# 7              0              1                0                 1
# 8              0              1                0                 0
# 9              1              0                0                 1
# 10             0              1                0                 1
# 11             0              0                0                 1
# 12             0              0                1                 0
# ...

# %%
tree.plot_tree(dt)
# Out:
# [Text(0.5555555555555556, 0.875, 'X[17] <= 0.5\ngini = 0.459\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.3333333333333333, 0.625, 'X[14] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.2222222222222222, 0.375, 'X[12] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7777777777777778, 0.625, 'X[4] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8888888888888888, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
for i in range(20):
    print(df["day"].sample(14))
# Out:
# 5      6
# 1      2
# 8      9
# 4      5
# 10    11
# 11    12
# 0      1
# 12    13
# 7      8
# 2      3
# 3      4
# 6      7
# 13    14
# 9     10
# Name: day, dtype: int64
# 10    11
# 0      1
# 7      8
# 4      5
# 5      6
# 9     10
# 6      7
# 3      4
# 11    12
# 13    14
# 1      2
# 8      9
# 2      3
# 12    13
# Name: day, dtype: int64
# 7      8
# 0      1
# 11    12
# 5      6
# 8      9
# 1      2
# 3      4
# 6      7
# 13    14
# 9     10
# 2      3
# 12    13
# 10    11
# 4      5
# Name: day, dtype: int64
# 7      8
# 1      2
# 0      1
# 6      7
# 11    12
# 4      5
# 2      3
# 13    14
# 10    11
# 9     10
# 12    13
# 8      9
# 3      4
# 5      6
# Name: day, dtype: int64
# 10    11
# 2      3
# 0      1
# 5      6
# 11    12
# 1      2
# 12    13
# 4      5
# 13    14
# 8      9
# 3      4
# 7      8
# 6      7
# 9     10
# Name: day, dtype: int64
# 9     10
# 2      3
# 7      8
# 5      6
# 0      1
# 10    11
# 3      4
# 6      7
# 8      9
# ...
